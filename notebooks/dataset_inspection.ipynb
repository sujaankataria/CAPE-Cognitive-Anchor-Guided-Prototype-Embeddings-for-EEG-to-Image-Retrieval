# %% [markdown]
# # CAPE Dataset Inspection
#
# Read-only inspection of one THINGS-EEG2 subject's preprocessed EEG arrays, image metadata, and image-set counts. The report is written to `results/dataset_inspection_report.txt`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))
from preprocessing.inspect_dataset import inspect_dataset

inspect_dataset("sub-01")
